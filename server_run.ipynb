# %% [markdown]
# ## CNN

# %% [markdown]
# ### CNN Baseline Runs

# %%
# Image + Gene Expression
# !python main.py --config_path configs/cnn_config.yaml

# %%
# Image (with randomly initialized weights) + Gene Expression
# !python main.py --config_path configs/cnn_config.yaml

# %%
# Gene Expression only
# !python main.py --config_path configs/cnn_config.yaml

# %%
# Image only
# !python main.py --config_path configs/cnn_config.yaml

# %% [markdown]
# ### CNN Hyperparameter Tuning

# %%
# !python sweeps.py --config_path configs/config.yaml\
--sweep_config_path configs/sweeps_config.yaml\
--sweep_project_name spt_resnet18_sweep\
--sweep_count 200

# %% [markdown]
# ### Graphs

# %% [markdown]
# First I will try embedding concatenation

# %%
# GCN - Resnet 18 - Concat
# !python main.py --config_path configs/image_model_configs/resnet_18_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_053148-hn5y8mb0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet-18-graph
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/hn5y8mb0
# Best model loaded.
# test loss: 0.0559, test rmse: 0.2364, test mae: 0.1704, test pearson_corr: 0.7144, test spearman_corr: 0.5321, wandb: 🚀 View run resnet-18-graph at: https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/hn5y8mb0
# wandb: Find logs at: wandb/run-20250310_053148-hn5y8mb0/logs

# %%
# GAT-4 - Resnet 18 - Concat
# !python main.py --config_path configs/image_model_configs/resnet_18_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_054912-9ontan1v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet-18-graph
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/9ontan1v
# Best model loaded.
# test loss: 0.0571, test rmse: 0.2390, test mae: 0.1738, test pearson_corr: 0.6937, test spearman_corr: 0.5182, wandb: 🚀 View run resnet-18-graph at: https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/9ontan1v
# wandb: Find logs at: wandb/run-20250310_054912-9ontan1v/logs

# %% [markdown]
# Now, I am experimenting Gated Fusion method

# %%
# GCN - Resnet 18 - Gated
# !python main.py --config_path configs/image_model_configs/resnet_18_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_060549-g0xnj0q5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet-18-graph
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/g0xnj0q5
# Best model loaded.
# test loss: 0.0545, test rmse: 0.2334, test mae: 0.1712, test pearson_corr: 0.7355, test spearman_corr: 0.5648, wandb: 🚀 View run resnet-18-graph at: https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/g0xnj0q5
# wandb: Find logs at: wandb/run-20250310_060549-g0xnj0q5/logs

# %%
# GAT4 - Resnet 18 - Gated
# !python main.py --config_path configs/image_model_configs/resnet_18_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_062603-bc6s5jm0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet-18-graph
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/bc6s5jm0
# Best model loaded.
# test loss: 0.0576, test rmse: 0.2400, test mae: 0.1775, test pearson_corr: 0.7276, test spearman_corr: 0.5690, wandb: 🚀 View run resnet-18-graph at: https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/bc6s5jm0
# wandb: Find logs at: wandb/run-20250310_062603-bc6s5jm0/logs

# %% [markdown]
# ## ViT

# %% [markdown]
# ### ViT Baseline Runs

# %%
# pretrained vit
from main import main
from argparse import Namespace
args = Namespace(config_path='configs/vit_config.yaml')
main(args)

# %%
# randomly initialized vit
from main import main
from argparse import Namespace
args = Namespace(config_path='configs/vit_config.yaml')
main(args)

# %%
# Image (with randomly initialized weights) + Gene Expression
# !python main.py --config_path configs/vit_config.yaml

# %%
# Image + Gene Expression
# !python main.py --config_path configs/vit_config.yaml

# %% [markdown]
# ### Graphs

# %%
# VIT - GCN - Gated
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_065727-bqopqqs1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/bqopqqs1
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Best model loaded.
# ...

# %%
# VIT - GAT - Gated
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_081003-kv1w9nan
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/kv1w9nan
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.

# %%
# VIT - GCN - Concat
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250310_092348-o34yq7vx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/o34yq7vx
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.

# %%
# VIT - GAT - Gated - BS 256
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250316_123839-17185dca
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k-bs256
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/17185dca
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Best model loaded.
# ...

# %%
# VIT - GAT - Gated - Num Genes 4000
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250316_134908-uvjq1ksc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k-gene4k
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/uvjq1ksc
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Best model loaded.
# ...

# %%
# VIT - GAT - Gated - Graph K 7
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250316_151723-4gd0ypwb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k-k7
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/4gd0ypwb
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Best model loaded.
# ...

# %%
# VIT - GAT - Gated - Graph K 7 - Patch Size 128
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250316_162922-riqdo72k
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k-k7-p128
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/riqdo72k
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.

# %%
# VIT - GAT - Concat - Graph K 7
# !python main.py --config_path configs/image_model_configs/vit-base_graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250326_104047-zwuw9fav
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit-base-16-in21k-k7-concat
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/zwuw9fav
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.

# %% [markdown]
# ## UNI

# %%
# UNI - GAT - Concat - Graph K 7

import os
os.environ["HF_TOKEN"] = "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"

# !python main.py --config_path configs/image_model_configs/uni-graph.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20250327_085231-jdflr9ew
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run uni-GAT-7-gated
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics_hf/runs/jdflr9ew
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# UNI - Concat

import os
os.environ["HF_TOKEN"] = "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"

# !python main.py --config_path configs/image_model_configs/uni-graph.yaml
