# %% [markdown]
# ## CNN

# %% [markdown]
# ### CNN Baseline Runs

# %%
# Image (with randomly initialized weights) + Gene Expression
# !python main.py --config_path configs/cnn_config.yaml

# %%
# Image + Gene Expression
# !python main.py --config_path configs/cnn_config.yaml
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mpekey_su. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.6
# wandb: Run data is saved locally in /ihome/hosmanbeyoglu/mpekey/spatial_transcriptomics/spt_research/wandb/run-20241111_030641-vdjwf9sr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resnet18
# wandb: ⭐️ View project at https://wandb.ai/mpekey_su/spatial_transcriptomics
# wandb: 🚀 View run at https://wandb.ai/mpekey_su/spatial_transcriptomics/runs/vdjwf9sr
# Epoch [1/100]
# train loss: 0.6854, train rmse: 0.8279, train mae: 0.7122, train pearson_corr: 0.0404, train spearman_corr: 0.0055, val loss: 0.2088, val rmse: 0.4568, val mae: 0.3432, val pearson_corr: 0.0748, val spearman_corr: 0.0335,
# Epoch [2/100]
# ...

# %%
# Gene Expression only
# !python main.py --config_path configs/cnn_config.yaml

# %%
# Image only
# !python main.py --config_path configs/cnn_config.yaml

# %% [markdown]
# ### CNN Hyperparameter Tuning

# %%
# !python sweeps.py --config_path configs/config.yaml\
--sweep_config_path configs/sweeps_config.yaml\
--sweep_project_name spt_resnet18_sweep\
--sweep_count 200

# %% [markdown]
# ## ViT

# %% [markdown]
# ### ViT Baseline Runs

# %%
# pretrained vit
from main import main
from argparse import Namespace
args = Namespace(config_path='configs/vit_config.yaml')
main(args)

# %%
# randomly initialized vit
from main import main
from argparse import Namespace
args = Namespace(config_path='configs/vit_config.yaml')
main(args)

# %%
# Image (with randomly initialized weights) + Gene Expression
# !python main.py --config_path configs/vit_config.yaml

# %%
# Image + Gene Expression
# !python main.py --config_path configs/vit_config.yaml
